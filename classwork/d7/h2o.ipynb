# %% [markdown]
# # Spark + H2O

# %%
import pickle
import pandas as pd
import numpy as np
from pysparkling import *
import h2o
from h2o.estimators.gbm import H2OGradientBoostingEstimator
from h2o.estimators.random_forest import H2ORandomForestEstimator
from h2o.grid.grid_search import H2OGridSearch
from utils import SEED

# %%
from pyspark.sql import SparkSession

spark = SparkSession.\
        builder.\
        appName("best_one").\
        master("spark://spark-master:7077").\
        config("spark.executor.memory", "512m").\
        getOrCreate()

# %%
with open('train_set_sru.pickle', mode='rb') as f:
    train_set = pickle.load(f)

# %%
with open('test_set.pickle', mode='rb') as f:
    test_set = pickle.load(f)

# %%
df_train = pd.DataFrame(train_set['x'], columns=train_set['x'].columns)
df_train['Results'] = train_set['y']

# %%
# в Spark DF
spark_df_train = spark.createDataFrame(df_train)

# %%
# H2O инит
hc = H2OContext.getOrCreate(spark)
# Out:
# Connecting to H2O server at http://ec2-34-253-225-131.eu-west-1.compute.amazonaws.com:54323... successful.
# --------------------------  ---------------------------------------------------------------
# H2O cluster uptime:         2 mins 11 secs
# H2O cluster version:        3.14.0.2
# H2O cluster version age:    21 days, 6 hours and 30 minutes
# H2O cluster name:           sparkling-water-root_app-20170912044422-0017
# H2O cluster total nodes:    2
# H2O cluster free memory:    3.845 Gb
# H2O cluster total cores:    4
# H2O cluster allowed cores:  4
# H2O cluster status:         locked, healthy
# H2O connection url:         http://ec2-34-253-225-131.eu-west-1.compute.amazonaws.com:54323
# H2O connection proxy:
# H2O internal security:      False
# H2O API Extensions:         AutoML, XGBoost, Algos, Core V3, Core V4
# Python version:             3.5.1 final
# --------------------------  ---------------------------------------------------------------

# %%
# в h2o DF
df_train_h2o = hc.as_h2o_frame(spark_df_train, "phishing_websites_train")

# %%
for col in list(df_train.columns):
    df_train_h2o[col] = df_train_h2o[col].asfactor()

# %%
df_test = pd.DataFrame(test_set['x'], columns=test_set['x'].columns)
df_test['Results'] = test_set['y']

spark_df_test = spark.createDataFrame(df_test)

df_test_h2o = hc.as_h2o_frame(spark_df_test, "phishing_websites_test")

for col in list(df_test.columns):
    df_test_h2o[col] = df_test_h2o[col].asfactor()

# %% [markdown]
# ## Grandient Boosting

# %%
# выбор модели
gbm_model = H2OGradientBoostingEstimator(
                                         distribution = "bernoulli",
                                         nfolds=5,
                                         seed=SEED
                                        )

tuned_parameters = {'ntrees': [10, 50, 70, 80, 90, 100
                              ],
                    'max_depth': [4, 8, 15
                                 ],
                    'learn_rate': [0.1, 0.2, 0.5
                                  ],
                    'min_split_improvement': [0.002, 0.005, 0.01
                                             ],
                    'col_sample_rate_per_tree': [5/len(train_set['x'].columns), 
                                                8/len(train_set['x'].columns), 
                                                10/len(train_set['x'].columns)
                                               ],
                    'col_sample_rate_change_per_level': [1, 0.5, 0.2
                                                        ]}


search_criteria = {
  "strategy": "RandomDiscrete", 
  "max_runtime_secs": 2700,
  "stopping_metric": "AUC",
  "stopping_tolerance": 0.00001, 
  "seed": SEED 
}

# тестируем с GRIDSEARCH
gs = H2OGridSearch(gbm_model, tuned_parameters, search_criteria=search_criteria)

gs.train(x=list(range(0, (len(df_train.columns)-1) ))
         ,y=29, training_frame=df_train_h2o)

grid = gs.get_grid(sort_by='Precision', decreasing=True)

best_model_id = grid.model_ids[0]
print(gs.get_hyperparams(best_model_id))
best_model_gbm = h2o.get_model(best_model_id)
# Out:
# gbm Grid Build progress: |████████████████████████████████████████████████| 100%
# Hyperparameters: [col_sample_rate_per_tree, col_sample_rate_change_per_level, min_split_improvement, learn_rate, ntrees, max_depth]
# [0.3333333333333333, 1.0, 0.005, 0.1, 80, 15]

# %%
print(gs.summary())
# Out:
# Grid Summary:
# Model Id                                                       number_of_trees    number_of_internal_trees    model_size_in_bytes    min_depth    max_depth    mean_depth    min_leaves    max_leaves    mean_leaves
# -------------------------------------------------------------  -----------------  --------------------------  ---------------------  -----------  -----------  ------------  ------------  ------------  -------------
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_6   80                 80                          42607                  0            12           5.9875        1             197           37.4
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_3   90                 90                          22266                  0            9            5.34444       1             34            14.6889
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_11  100                100                         20236                  0            10           2.22          1             112           10.93
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_16  100                100                         10972                  0            4            1.52          1             13            3.59
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_15  80                 80                          13714                  2            8            4.5           1             22            8.6875
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_10  50                 50                          5018                   0            8            1.3           1             13            2.82
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_8   70                 70                          7276                   0            4            1.52857       1             9             3.14286
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_1   50                 50                          4728                   0            5            0.92          1             12            2.36
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_12  90                 90                          9333                   0            4            1.04444       1             15            3.06667
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_5   70                 70                          7346                   0            7            1.48571       1             14            3.2
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_13  50                 50                          5621                   1            4            2.08          1             10            3.9
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_2   70                 70                          6633                   0            4            1.04286       1             9             2.38571
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_17  10                 10                          2159                   3            6            5.1           5             19            12.3
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_4   10                 10                          1234                   2            4            2.9           1             9             4.9
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_14  70                 70                          10168                  3            6            3.42857       1             15            6.57143
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_7   10                 10                          1333                   2            5            3.1           1             9             5.7
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_0   10                 10                          6762                   6            12           8.5           9             143           49
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_18  15                 15                          1789                   2            4            2.66667       1             7             4.53333
# Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_9   10                 10                          2360                   4            4            4             9             16            13.9
# None

# %%
print(gs.sorted_metric_table())
# Out:
#      col_sample_rate_change_per_level col_sample_rate_per_tree learn_rate  \
# 0                                 1.0       0.3333333333333333        0.1
# 1                                 0.5       0.3333333333333333        0.1
# 2                                 1.0      0.26666666666666666        0.2
# 3                                 0.2       0.3333333333333333        0.2
# 4                                 0.2       0.3333333333333333        0.1
# 5                                 0.2       0.3333333333333333        0.5
# 6                                 0.2       0.3333333333333333        0.2
# 7                                 0.5      0.16666666666666666        0.5
# 8                                 1.0      0.26666666666666666        0.2
# 9                                 0.5       0.3333333333333333        0.2
# 10                                0.5      0.16666666666666666        0.2
# 11                                0.2       0.3333333333333333        0.2
# 12                                0.5       0.3333333333333333        0.5
# 13                                0.2      0.26666666666666666        0.5
# 14                                0.5      0.16666666666666666        0.1
# 15                                0.2      0.16666666666666666        0.5
# 16                                1.0       0.3333333333333333        0.2
# 17                                0.5      0.16666666666666666        0.1
# 18                                1.0       0.3333333333333333        0.1
#
#    max_depth min_split_improvement ntrees  \
# 0         15                 0.005     80
# 1         15                 0.002     90
# 2         15                 0.005    100
# 3          4                 0.002    100
# 4          8                 0.002     80
# 5         15                 0.005     50
# 6          4                 0.005     70
# 7         15                 0.005     50
# 8          4                  0.01     90
# 9         15                  0.01     70
# 10         4                 0.005     50
# 11         4                  0.01     70
# 12         8                 0.005     10
# 13         4                 0.005     10
# 14        15                 0.002     70
# 15         8                 0.002     10
# 16        15                  0.01     10
# 17         8                  0.01     15
# 18         4                 0.005     10
#
#                                                         model_ids  \
# 0    Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_6
# 1    Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_3
# 2   Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_11
# 3   Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_16
# 4   Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_15
# 5   Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_10
# 6    Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_8
# 7    Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_1
# 8   Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_12
# 9    Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_5
# 10  Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_13
# 11   Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_2
# 12  Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_17
# 13   Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_4
# 14  Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_14
# 15   Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_7
# 16   Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_0
# 17  Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_18
# 18   Grid_GBM_py_30_sid_ac21_model_python_1505191582243_1_model_9
#
#                 logloss
# 0   0.14357329651280587
# 1   0.14408885951991188
# 2   0.14929870550355734
# 3    0.1543458034392661
# 4   0.15875159391123544
# 5   0.16339720744907468
# 6    0.1718744965040586
# 7   0.17384623592834642
# 8   0.17801125300775822
# 9   0.17885098852246395
# 10  0.18604614834381128
# 11  0.18766298797205935
# 12  0.19141609590066652
# 13  0.21695089070640775
# 14  0.21995686650990376
# 15  0.23800646475179507
# 16   0.2885591318165788
# 17  0.41264636889692574
# 18  0.42328600835828867

# %%
# повторяем над тестовым DF
df_test = pd.DataFrame(test_set['x'], columns=test_set['x'].columns)
df_test['Results'] = test_set['y']

spark_df_test = spark.createDataFrame(df_test)

df_test_h2o = hc.as_h2o_frame(spark_df_test, "phishing_websites_test")

for col in list(df_test.columns):
    df_test_h2o[col] = df_test_h2o[col].asfactor()

# %%
performance_test = best_model_gbm.model_performance(df_test_h2o)

print(performance_test)
# Out:
# ModelMetricsBinomial: gbm
# ** Reported on test data. **
#
# MSE: 0.038409138690364206
# RMSE: 0.19598249587747424
# LogLoss: 0.14552904445966308
# Mean Per-Class Error: 0.04365552337747125
# AUC: 0.9900174933458326
# Gini: 0.9800349866916651
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.46020107046395525:
#        -1    1     Error    Rate
# -----  ----  ----  -------  -------------
# -1     886   54    0.0574   (54.0/940.0)
# 1      40    1231  0.0315   (40.0/1271.0)
# Total  926   1285  0.0425   (94.0/2211.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0.460201     0.963224  226
# max f2                       0.371984     0.969555  247
# max f0point5                 0.630511     0.968603  190
# max accuracy                 0.460201     0.957485  226
# max precision                0.994222     1         0
# max recall                   0.0459753    1         356
# max specificity              0.994222     1         0
# max absolute_mcc             0.460201     0.912929  226
# max min_per_class_accuracy   0.560433     0.955319  207
# max mean_per_class_accuracy  0.603244     0.956344  197
# Gains/Lift Table: Avg response rate: 57.49 %
#     group    cumulative_data_fraction    lower_threshold    lift       cumulative_lift    response_rate    cumulative_response_rate    capture_rate    cumulative_capture_rate    gain      cumulative_gain
# --  -------  --------------------------  -----------------  ---------  -----------------  ---------------  --------------------------  --------------  -------------------------  --------  -----------------
#     1        0.0104025                   0.990427           1.73958    1.73958            1                1                           0.018096        0.018096                   73.9575   73.9575
#     2        0.0208051                   0.989396           1.73958    1.73958            1                1                           0.018096        0.036192                   73.9575   73.9575
#     3        0.030303                    0.988553           1.73958    1.73958            1                1                           0.0165224       0.0527144                  73.9575   73.9575
#     4        0.0402533                   0.987458           1.73958    1.73958            1                1                           0.0173092       0.0700236                  73.9575   73.9575
#     5        0.0502035                   0.986276           1.73958    1.73958            1                1                           0.0173092       0.0873328                  73.9575   73.9575
#     6        0.100407                    0.980318           1.73958    1.73958            1                1                           0.0873328       0.174666                   73.9575   73.9575
#     7        0.150158                    0.975353           1.73958    1.73958            1                1                           0.086546        0.261212                   73.9575   73.9575
#     8        0.201266                    0.968876           1.73958    1.73958            1                1                           0.0889064       0.350118                   73.9575   73.9575
#     9        0.300769                    0.950217           1.73167    1.73696            0.995455         0.998496                    0.172305        0.522423                   73.1668   73.6959
#     10       0.400724                    0.91792            1.72383    1.73368            0.99095          0.996614                    0.172305        0.694729                   72.3832   73.3685
#     11       0.500226                    0.777081           1.62887    1.71284            0.936364         0.984629                    0.162077        0.856806                   62.8875   71.2837
#     12       0.600181                    0.362199           1.21219    1.62946            0.696833         0.936699                    0.121164        0.97797                    21.2193   62.9459
#     13       0.700136                    0.0855645          0.204656   1.42605            0.117647         0.819767                    0.0204563       0.998426                   -79.5344  42.6047
#     14       0.80009                     0.0192783          0.0157428  1.24986            0.00904977       0.718485                    0.00157356      1                          -98.4257  24.9859
#     15       0.900045                    0.0117676          0          1.11106            0                0.638693                    0               1                          -100      11.1055
#     16       1                           0.0047988          0          1                  0                0.574853                    0               1                          -100      0

# %%
print(performance_test.accuracy()[0][1])
# Out:
# 0.9574853007688828

# %% [markdown]
# ## Random Forest

# %%
rf_model = H2ORandomForestEstimator(
                                     nfolds=5,
                                     seed=SEED,
                                     fold_assignment='Stratified'
                                    )

tuned_parameters = {'ntrees': [50, 100, 200],
                    'mtries': [-1],
                    'max_depth': [4, 8, 10, 15],
                    'min_rows': [0.02, 0.05, 0.1]
                   }

search_criteria = {
  "strategy": "RandomDiscrete", 
  "max_runtime_secs": 1800, 
  "stopping_metric": "AUC",
  "stopping_tolerance": 0.00001,
  "seed": SEED 
}

# %%
# grid search
gs = H2OGridSearch(rf_model, tuned_parameters, search_criteria=search_criteria)

# %%
gs.train(x=list(range(0, (len(df_train.columns)-1) )), y=29, training_frame=df_train_h2o)
# Out:
# drf Grid Build progress: |████████████████████████████████████████████████| 100%

# %%
grid = gs.get_grid(sort_by='Precision', decreasing=True)

best_model_id = grid.model_ids[0]
print(gs.get_hyperparams(best_model_id))
best_model_rf = h2o.get_model(best_model_id)
# Out:
# Hyperparameters: [min_rows, mtries, ntrees, max_depth]
# [0.02, -1, 200, 15]

# %%
print(gs.summary())
# Out:
# Grid Summary:
# Model Id                                                           number_of_trees    number_of_internal_trees    model_size_in_bytes    min_depth    max_depth    mean_depth    min_leaves    max_leaves    mean_leaves
# -----------------------------------------------------------------  -----------------  --------------------------  ---------------------  -----------  -----------  ------------  ------------  ------------  -------------
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_17  200                200                         897903                 15           15           15            256           477           352.815
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_27  200                200                         897905                 15           15           15            256           477           352.815
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_0   200                200                         897898                 15           15           15            256           477           352.815
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_16  100                100                         449469                 15           15           15            256           477           353.3
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_5   100                100                         449466                 15           15           15            256           477           353.3
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_14  50                 50                          218406                 15           15           15            273           477           343.3
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_10  50                 50                          218399                 15           15           15            273           477           343.3
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_25  50                 50                          218403                 15           15           15            273           477           343.3
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_24  100                100                         242896                 10           10           10            134           258           188.51
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_3   50                 50                          117321                 10           10           10            134           258           182.02
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_21  50                 50                          117323                 10           10           10            134           258           182.02
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_15  50                 50                          117324                 10           10           10            134           258           182.02
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_8   200                200                         483520                 10           10           10            116           259           187.58
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_26  200                200                         483517                 10           10           10            116           259           187.58
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_28  15                 15                          36692                  10           10           10            163           247           189.933
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_11  50                 50                          65960                  8            8            8             68            145           99.94
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_23  50                 50                          65959                  8            8            8             68            145           99.94
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_1   50                 50                          65956                  8            8            8             68            145           99.94
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_19  100                100                         135377                 8            8            8             68            145           102.7
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_2   100                100                         135380                 8            8            8             68            145           102.7
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_22  200                200                         270221                 8            8            8             62            145           102.48
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_4   200                200                         270227                 8            8            8             62            145           102.48
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_18  50                 50                          11798                  4            4            4             9             16            13.86
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_12  50                 50                          11799                  4            4            4             9             16            13.86
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_6   50                 50                          11800                  4            4            4             9             16            13.86
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_13  100                100                         23737                  4            4            4             9             16            13.96
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_20  100                100                         23734                  4            4            4             9             16            13.96
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_9   200                200                         47710                  4            4            4             8             16            14.01
# Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_7   200                200                         47706                  4            4            4             8             16            14.01
# None

# %%
print(gs.sorted_metric_table())
# Out:
#      max_depth min_rows mtries ntrees  \
# 0           15     0.02     -1    200
# 1           15     0.05     -1    200
# 2           15      0.1     -1    200
# 3           15     0.02     -1    100
# 4           15      0.1     -1    100
# 5           15     0.05     -1     50
# 6           15     0.02     -1     50
# 7           15      0.1     -1     50
# 8           10     0.02     -1    100
# 9           10      0.1     -1     50
# 10          10     0.02     -1     50
# 11          10     0.05     -1     50
# 12          10      0.1     -1    200
# 13          10     0.05     -1    200
# 14          10     0.02     -1     15
# 15           8      0.1     -1     50
# 16           8     0.05     -1     50
# 17           8     0.02     -1     50
# 18           8     0.02     -1    100
# 19           8      0.1     -1    100
# 20           8     0.02     -1    200
# 21           8      0.1     -1    200
# 22           4      0.1     -1     50
# 23           4     0.02     -1     50
# 24           4     0.05     -1     50
# 25           4     0.05     -1    100
# 26           4      0.1     -1    100
# 27           4      0.1     -1    200
# 28           4     0.02     -1    200
#
#                                                             model_ids  \
# 0   Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_17
# 1   Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_27
# 2    Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_0
# 3   Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_16
# 4    Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_5
# 5   Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_14
# 6   Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_10
# 7   Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_25
# 8   Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_24
# 9    Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_3
# 10  Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_21
# 11  Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_15
# 12   Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_8
# 13  Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_26
# 14  Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_28
# 15  Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_11
# 16  Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_23
# 17   Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_1
# 18  Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_19
# 19   Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_2
# 20  Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_22
# 21   Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_4
# 22  Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_18
# 23  Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_12
# 24   Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_6
# 25  Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_13
# 26  Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_20
# 27   Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_9
# 28   Grid_DRF_py_30_sid_bf3c_model_python_1505155590336_19525_model_7
#
#                 logloss
# 0    0.1000103779586281
# 1    0.1000103779586281
# 2    0.1000103779586281
# 3   0.10004781157509561
# 4   0.10004781157509561
# 5   0.10068590190095618
# 6   0.10068590190095618
# 7   0.10068590190095618
# 8    0.1332083571233345
# 9   0.13330038449901366
# 10  0.13330038449901366
# 11  0.13330038449901366
# 12  0.13393068326949478
# 13  0.13393068326949478
# 14  0.13426458775945238
# 15  0.16325590087251093
# 16  0.16325590087251093
# 17  0.16325590087251093
# 18   0.1643631036921758
# 19   0.1643631036921758
# 20   0.1651672469551957
# 21   0.1651672469551957
# 22   0.2642289395575128
# 23   0.2642289395575128
# 24   0.2642289395575128
# 25   0.2682020709045653
# 26   0.2682020709045653
# 27   0.2704231968644725
# 28   0.2704231968644725

# %%
performance_test = best_model_rf.model_performance(df_test_h2o)

print(performance_test)
# Out:
# ModelMetricsBinomial: drf
# ** Reported on test data. **
#
# MSE: 0.027665373213013794
# RMSE: 0.16632911114117635
# LogLoss: 0.10509879056943468
# Mean Per-Class Error: 0.0302802283341983
# AUC: 0.9955199457622579
# Gini: 0.9910398915245158
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.48991800505667926:
#        -1    1     Error    Rate
# -----  ----  ----  -------  -------------
# -1     906   34    0.0362   (34.0/940.0)
# 1      31    1240  0.0244   (31.0/1271.0)
# Total  937   1274  0.0294   (65.0/2211.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0.489918     0.97446   221
# max f2                       0.255494     0.982641  271
# max f0point5                 0.597885     0.977049  196
# max accuracy                 0.489918     0.970602  221
# max precision                0.999996     1         0
# max recall                   0.100656     1         320
# max specificity              0.999996     1         0
# max absolute_mcc             0.489918     0.939834  221
# max min_per_class_accuracy   0.513805     0.967742  215
# max mean_per_class_accuracy  0.489918     0.96972   221
# Gains/Lift Table: Avg response rate: 57.49 %
#     group    cumulative_data_fraction    lower_threshold    lift     cumulative_lift    response_rate    cumulative_response_rate    capture_rate    cumulative_capture_rate    gain     cumulative_gain
# --  -------  --------------------------  -----------------  -------  -----------------  ---------------  --------------------------  --------------  -------------------------  -------  -----------------
#     1        0.0104025                   0.999851           1.73958  1.73958            1                1                           0.018096        0.018096                   73.9575  73.9575
#     2        0.0221619                   0.999693           1.73958  1.73958            1                1                           0.0204563       0.0385523                  73.9575  73.9575
#     3        0.0307553                   0.999515           1.73958  1.73958            1                1                           0.0149489       0.0535012                  73.9575  73.9575
#     4        0.0407056                   0.999278           1.73958  1.73958            1                1                           0.0173092       0.0708104                  73.9575  73.9575
#     5        0.0502035                   0.999055           1.73958  1.73958            1                1                           0.0165224       0.0873328                  73.9575  73.9575
#     6        0.100407                    0.997514           1.73958  1.73958            1                1                           0.0873328       0.174666                   73.9575  73.9575
#     7        0.150158                    0.994678           1.73958  1.73958            1                1                           0.086546        0.261212                   73.9575  73.9575
#     8        0.200362                    0.989745           1.73958  1.73958            1                1                           0.0873328       0.348544                   73.9575  73.9575
#     9        0.300317                    0.975016           1.73958  1.73958            1                1                           0.173879        0.522423                   73.9575  73.9575
#     10       0.400271                    0.939806           1.73958  1.73958            1                1                           0.173879        0.696302                   73.9575  73.9575
#     11       0.500226                    0.824596           1.6766   1.72699            0.963801         0.992767                    0.167585        0.863887                   67.6604  72.6992
#     12       0.600633                    0.313447           1.24591  1.64657            0.716216         0.946536                    0.125098        0.988985                   24.5912  64.6571
#     13       0.700136                    0.050998           0.1107   1.42829            0.0636364        0.821059                    0.0110149       1                          -88.93   42.8295
#     14       0.800543                    0.00805229         0        1.24915            0                0.718079                    0               1                          -100     24.9153
#     15       0.900045                    0.00171915         0        1.11106            0                0.638693                    0               1                          -100     11.1055
#     16       1                           0                  0        1                  0                0.574853                    0               1                          -100     0

# %%
print(performance_test.accuracy()[0][1])
# Out:
# 0.9706015377657169
